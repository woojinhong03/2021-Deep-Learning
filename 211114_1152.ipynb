# %% [markdown]
# <a href="https://colab.research.google.com/github/woojinhong03/2021-Deep-Learning/blob/main/211114_1152.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = input().split()
 
print(len(n))
